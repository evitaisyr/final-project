# %%
import pandas as pd

# Read the CSV file
file_path = '/Users/lizvitai/Documents/Pythonsports/lakers_2024_schedule.csv'
df = pd.read_csv(file_path, header=None)

# Set the second row as the header and drop the first row
df.columns = df.iloc[1]
df = df.drop(index=[0, 1])

# Replace NaN values with blank strings
df = df.fillna('')

# Create a list of columns to drop (those containing 'nan', 'Start (ET)', 'Notes')
columns_to_drop = [col for col in df.columns if 'nan' in str(col) or col in ['Start (ET)', 'Notes']]

# Drop the irrelevant columns
df = df.drop(columns=columns_to_drop)

# Drop rows that don't have important values (e.g., missing 'Date' and 'Opponent')
df = df.dropna(subset=['Date', 'Opponent'])

# Ensure 'Date' column is in datetime format
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Calculate 'Days Ago' from the 'Date' column
current_date = pd.to_datetime('today')
df['Days Ago'] = (current_date - df['Date']).dt.days

# Reset index to clean up gaps after dropping columns and rows
df = df.reset_index(drop=True)

# Save the cleaned DataFrame to a new CSV file
output_file_path = '/Users/lizvitai/Documents/Pythonsports/lakers_2024_schedule_cleaned.csv'
df.to_csv(output_file_path, index=False)

# Confirm that the file has been saved
print(f"Cleaned CSV file has been saved to {output_file_path}")

# Apply some styles to the DataFrame to make it look better
styled_df = df.style.set_properties(subset=['Opponent', 'Tm', 'Opp'], **{'text-align': 'center'})
styled_df = styled_df.format({'Date': lambda x: x.strftime('%Y-%m-%d'), 'Days Ago': '{:.0f}'})  # Format Date and Days Ago

# Display the styled DataFrame
styled_df
# Out:
# Cleaned CSV file has been saved to /Users/lizvitai/Documents/Pythonsports/lakers_2024_schedule_cleaned.csv
# <style type="text/css">
# #T_9441d_row0_col2, #T_9441d_row0_col3, #T_9441d_row0_col4, #T_9441d_row1_col2, #T_9441d_row1_col3, #T_9441d_row1_col4, #T_9441d_row2_col2, #T_9441d_row2_col3, #T_9441d_row2_col4, #T_9441d_row3_col2, #T_9441d_row3_col3, #T_9441d_row3_col4, #T_9441d_row4_col2, #T_9441d_row4_col3, #T_9441d_row4_col4, #T_9441d_row5_col2, #T_9441d_row5_col3, #T_9441d_row5_col4, #T_9441d_row6_col2, #T_9441d_row6_col3, #T_9441d_row6_col4, #T_9441d_row7_col2, #T_9441d_row7_col3, #T_9441d_row7_col4, #T_9441d_row8_col2, #T_9441d_row8_col3, #T_9441d_row8_col4, #T_9441d_row9_col2, #T_9441d_row9_col3, #T_9441d_row9_col4, #T_9441d_row10_col2, #T_9441d_row10_col3, #T_9441d_row10_col4, #T_9441d_row11_col2, #T_9441d_row11_col3, #T_9441d_row11_col4, #T_9441d_row12_col2, #T_9441d_row12_col3, #T_9441d_row12_col4, #T_9441d_row13_col2, #T_9441d_row13_col3, #T_9441d_row13_col4, #T_9441d_row14_col2, #T_9441d_row14_col3, #T_9441d_row14_col4, #T_9441d_row15_col2, #T_9441d_row15_col3, #T_9441d_row15_col4, #T_9441d_row16
52_col4, #T_9441d_row53_col2, #T_9441d_row53_col3, #T_9441d_row53_col4, #T_9441d_row54_col2, #T_9441d_row54_col3, #T_9441d_row54_col4, #T_9441d_row55_col2, #T_9441d_row55_col3, #T_9441d_row55_col4, #T_9441d_row56_col2, #T_9441d_row56_col3, #T_9441d_row56_col4, #T_9441d_row57_col2, #T_9441d_row57_col3, #T_9441d_row57_col4, #T_9441d_row58_col2, #T_9441d_row58_col3, #T_9441d_row58_col4, #T_9441d_row59_col2, #T_9441d_row59_col3, #T_9441d_row59_col4, #T_9441d_row60_col2, #T_9441d_row60_col3, #T_9441d_row60_col4, #T_9441d_row61_col2, #T_9441d_row61_col3, #T_9441d_row61_col4, #T_9441d_row62_col2, #T_9441d_row62_col3, #T_9441d_row62_col4, #T_9441d_row63_col2, #T_9441d_row63_col3, #T_9441d_row63_col4 ...
#   text-align: center;
# }
# </style>
# <table id="T_9441d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >1</th>
#       <th id="T_9441d_level0_col0" class="col_heading level0 col0" >G</th>
#       <th id="T_9441d_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_9441d_level0_col2" class="col_heading level0 col2" >Opponent</th>
#       <th id="T_9441d_level0_col3" class="col_heading level0 col3" >Tm</th>
#       <th id="T_9441d_level0_col4" class="col_heading level0 col4" >Opp</th>
#       <th id="T_9441d_level0_col5" class="col_heading level0 col5" >W</th>
#       <th id="T_9441d_level0_col6" class="col_heading level0 col6" >L</th>
#       <th id="T_9441d_level0_col7" class="col_heading level0 col7" >Streak</th>
#       <th id="T_9441d_level0_col8" class="col_heading level0 col8" >Attend.</th>
#       <th id="T_9441d_level0_col9" class="col_heading level0 col9" >LOG</th>
#       <th id="T_9441d_level0_col10" class="col_heading level0 col10" >Days Ago</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9441d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9441d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9441d_row0_col1" class="data row0 col1" >2023-10-24</td>
#       <td id="T_9441d_row0_col2" class="data row0 col2" >Denver Nuggets</td>
#       <td id="T_9441d_row0_col3" class="data row0 col3" >107</td>
#       <td id="T_9441d_row0_col4" class="data row0 col4" >119</td>
#       <td id="T_9441d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_9441d_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_9441d_row0_col7" class="data row0 col7" >L 1</td>
#       <td id="T_9441d_row0_col8" class="data row0 col8" >19842</td>
#       <td id="T_9441d_row0_col9" class="data row0 col9" >2:17</td>
#       <td id="T_9441d_row0_col10" class="data row0 col10" >461</td>
#     </tr>
#     <tr>
#       <th id="T_9441d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9441d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9441d_row1_col1" class="data row1 col1" >2023-10-26</td>
#       <td id="T_9441d_row1_col2" class="data row1 col2" >Phoenix Suns</td>
#       <td id="T_9441d_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_9441d_row1_col4" class="data row1 col4" >95</td>
#       <td id="T_9441d_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_9441d_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_9441d_row1_col7" class="data row1 col7" >W 1</td>
#       <td id="T_9441d_row1_col8" class="data row1 col8" >18997</td>
#       <td id="T_9441d_row1_col9" class="data row1 col9" >2:26</td>
#       <td id="T_9441d_row1_col10" class="data row1 col10" >459</td>
#     </tr>
#     <tr>
#       <th id="T_9441d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id=
